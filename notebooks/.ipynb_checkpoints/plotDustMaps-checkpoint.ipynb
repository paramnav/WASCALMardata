# %% [markdown]
# Refer code from Willi: https://github.com/mardatade/2024_mardata_OSCM_challenge_2_firstlook/blob/main/notebooks/2024-03-13_prep_aod_sat_data.ipynb

# %%
willi_path = "/home/jovyan/shared_materials/challenge_2_data/MCD19A2/"

# %%
import xarray as xr
import cmocean

# %%
dust_caboverde = xr.open_dataset(willi_path + "MCD19A2.06_cabo_verde.nc")

# %%
dust_caboverde
# Out:
# <xarray.Dataset>
# Dimensions:            (lon: 66, lat: 50, time: 1302)
# Coordinates:
#   * lon                (lon) float64 -28.12 -27.88 -27.62 ... -12.12 -11.88
#   * lat                (lat) float64 7.875 8.125 8.375 ... 19.62 19.88 20.12
#     spatial_ref        int64 ...
#   * time               (time) datetime64[ns] 2022-12-29 ... 2024-03-05
#     fname              (time) object ...
# Data variables:
#     Optical_Depth_047  (time, lon, lat) float64 ...
#     Optical_Depth_055  (time, lon, lat) float64 ...

# %%
dust_caboverde.std("time").Optical_Depth_047.T.plot()

# %%
dust_caboverde.std("time").Optical_Depth_055.T.plot()

# %%
dust_caboverde.mean("time").Optical_Depth_055.T.plot()

# %%
dust_caboverde.Optical_Depth_047.mean("time")
# Out:
# <xarray.DataArray 'Optical_Depth_047' (lon: 66, lat: 50)>
# array([[       nan,        nan,        nan, ..., 0.29037725, 0.30974565,
#                nan],
#        [       nan,        nan,        nan, ..., 0.29742568, 0.32137988,
#                nan],
#        [       nan,        nan,        nan, ..., 0.3095142 , 0.3209543 ,
#                nan],
#        ...,
#        [0.41047877, 0.42557561, 0.45766724, ..., 0.33868474, 0.33323613,
#                nan],
#        [0.42559852, 0.44036508, 0.4703855 , ..., 0.3439699 , 0.32957527,
#                nan],
#        [0.44478739, 0.46048664, 0.47712559, ..., 0.36073293, 0.33668983,
#                nan]])
# Coordinates:
#   * lon          (lon) float64 -28.12 -27.88 -27.62 ... -12.38 -12.12 -11.88
#   * lat          (lat) float64 7.875 8.125 8.375 8.625 ... 19.62 19.88 20.12
#     spatial_ref  int64 0

# %%
import matplotlib.pyplot as plt


optical_depth_047_specific_day = dust_caboverde.sel(time="2023-02-10").Optical_Depth_047.mean("time")

#plt.figure(figsize=(10, 8))
img = optical_depth_047_specific_day.plot.imshow()

#plt.colorbar(img, label="Optical Depth")  
plt.show()

# %%
# Step 1: Find the mean if time steps are the same
mean_over_time = dust_caboverde.groupby('time').mean('time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 5
#       2 mean_over_time = dust_caboverde.groupby('time').mean('time')
#       4 # Step 2: Coarsen or average over 5 days
# ----> 5 dust_caboverde_coarsen = mean_over_time.coarsen(time=5).mean()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/rolling.py:1121, in DatasetCoarsen._reduce_method.<locals>.wrapped_func(self, keep_attrs, **kwargs)
#    1119 reduced = {}
#    1120 for key, da in self.obj.data_vars.items():
# -> 1121     reduced[key] = da.variable.coarsen(
#    1122         self.windows,
#    1123         func,
#    1124         self.boundary,
#    1125         self.side,
#    1126         keep_attrs=keep_attrs,
#    1127         **kwargs,
#    1128     )
#    1130 coords = {}
#    1131 for c, v in self.obj.coords.items():
#    1132     # variable.coarsen returns variables not containing the window dims
#    1133     # unchanged (maybe removes attrs)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/variable.py:2229, in Variable.coarsen(self, windows, func, boundary, side, keep_attrs, **kwargs)
#    2226 if not windows:
#    2227     return self._replace(attrs=_attrs)
# -> 2229 reshaped, axes = self.coarsen_reshape(windows, boundary, side)
#    2230 if isinstance(func, str):
#    2231     name = func
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/variable.py:2265, in Variable.coarsen_reshape(self, windows, boundary, side)
#    2263 if boundary[d] == "exact":
#    2264     if n * window != size:
# -> 2265         raise ValueError(
#    2266             f"Could not coarsen a dimension of size {size} with "
#    2267             f"window {window} and boundary='exact'. Try a different 'boundary' option."
#    2268         )
#    2269 elif boundary[d] == "trim":
#    2270     if side[d] == "left":
#
# ValueError: Could not coarsen a dimension of size 433 with window 5 and boundary='exact'. Try a different 'boundary' option.

# %%
mean_over_time.sel(time="2023-02-14").Optical_Depth_047.plot.imshow()

# %%
mean_over_time.time[:20]
# Out:
# <xarray.DataArray 'time' (time: 20)>
# array(['2022-12-29T00:00:00.000000000', '2022-12-30T00:00:00.000000000',
#        '2022-12-31T00:00:00.000000000', '2023-01-01T00:00:00.000000000',
#        '2023-01-02T00:00:00.000000000', '2023-01-03T00:00:00.000000000',
#        '2023-01-04T00:00:00.000000000', '2023-01-05T00:00:00.000000000',
#        '2023-01-06T00:00:00.000000000', '2023-01-07T00:00:00.000000000',
#        '2023-01-08T00:00:00.000000000', '2023-01-09T00:00:00.000000000',
#        '2023-01-10T00:00:00.000000000', '2023-01-11T00:00:00.000000000',
#        '2023-01-12T00:00:00.000000000', '2023-01-13T00:00:00.000000000',
#        '2023-01-14T00:00:00.000000000', '2023-01-15T00:00:00.000000000',
#        '2023-01-16T00:00:00.000000000', '2023-01-17T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     spatial_ref  int64 0
#   * time         (time) datetime64[ns] 2022-12-29 2022-12-30 ... 2023-01-17

# %%
# Step 2: Coarsen or average over 5 days
dust_caboverde_coarsen = mean_over_time.coarsen(time=5, boundary='pad').mean()

# %%
dust_caboverde_coarsen.time[0:20]
# Out:
# <xarray.DataArray 'time' (time: 20)>
# array(['2022-12-31T00:00:00.000000000', '2023-01-05T00:00:00.000000000',
#        '2023-01-10T00:00:00.000000000', '2023-01-15T00:00:00.000000000',
#        '2023-01-20T00:00:00.000000000', '2023-01-25T00:00:00.000000000',
#        '2023-01-30T00:00:00.000000000', '2023-02-04T00:00:00.000000000',
#        '2023-02-09T00:00:00.000000000', '2023-02-14T00:00:00.000000000',
#        '2023-02-19T00:00:00.000000000', '2023-02-24T00:00:00.000000000',
#        '2023-03-01T00:00:00.000000000', '2023-03-06T00:00:00.000000000',
#        '2023-03-11T00:00:00.000000000', '2023-03-16T00:00:00.000000000',
#        '2023-03-21T00:00:00.000000000', '2023-03-26T00:00:00.000000000',
#        '2023-03-31T00:00:00.000000000', '2023-04-05T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     spatial_ref  int64 0
#   * time         (time) datetime64[ns] 2022-12-31 2023-01-05 ... 2023-04-05

# %%
dust_caboverde_coarsen.sel(time="2023-02-14").Optical_Depth_047.plot.imshow()
